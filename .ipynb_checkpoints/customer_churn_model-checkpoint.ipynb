# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df2 = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df .head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG       0              0     Yes         No       1           No
# 1  5575-GNVDE       1              0      No         No      34          Yes
# 2  3668-QPYBK       1              0      No         No       2          Yes
# 3  7795-CFOCW       1              0      No         No      45           No
# 4  9237-HQITU       0              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# The model needs numerical data. So I need to convert all strings to numbers.
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
# one-hot encode all discrete features. All of them? what if "tenure" below, which is 73, actually is discrete and only can have 73 vals, we would have extra 72 cols then.
# Is that worth it?
# Sklearn has a method for that but it works alphabetically. So "high", and "Medium" values would 0, 1 which is misleading to me.
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
# Getting indices of cols whose value is either Yes or No
yes_no_cols = [col for col in df.columns if set(df[col].dropna().unique()) == {'Yes', 'No'}]

# %%
yes_no_cols
# Out:
# ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling', 'Churn']

# %%
# Gonna define a new data frame for the encoded dataset to keep a version of original dataset.
df_encoded = df
df_encoded.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_encoded[yes_no_cols]
# Out:
#      Partner Dependents PhoneService PaperlessBilling Churn
# 0        Yes         No           No              Yes    No
# 1         No         No          Yes               No    No
# 2         No         No          Yes              Yes   Yes
# 3         No         No           No               No    No
# 4         No         No          Yes              Yes   Yes
# ...      ...        ...          ...              ...   ...
# 7038     Yes        Yes          Yes              Yes    No
# 7039     Yes        Yes          Yes              Yes    No
# 7040     Yes        Yes           No              Yes    No
# 7041     Yes         No          Yes              Yes   Yes
# 7042      No         No          Yes              Yes    No
#
# [7043 rows x 5 columns]

# %%
df_encoded[yes_no_cols] = df_encoded[yes_no_cols].replace({'Yes': 1, 'No': 0})
df_encoded.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0       1          0       1            0
# 1  5575-GNVDE    Male              0       0          0      34            1
# 2  3668-QPYBK    Male              0       0          0       2            1
# 3  7795-CFOCW    Male              0       0          0      45            0
# 4  9237-HQITU  Female              0       0          0       2            1
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_encoded.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling     object
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                object
# dtype: object

# %%
df_encoded.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
# CustomerID wouldn't be a feature of course. keep it as is.
df_encoded['gender'] = df_encoded['gender'].replace({'Male': 1, "Female": 0})

# %%
df_encoded[['PhoneService', 'Partner', 'Dependents']].iloc[0:5]
# Out:
#   PhoneService Partner Dependents
# 0            0       1          0
# 1            1       0          0
# 2            1       0          0
# 3            0       0          0
# 4            1       0          0

# %%
df_encoded['Dependents'].unique()
# df_encoded['Partner'].unique()
# df_encoded['PhoneService'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
# Features whose values are either 0 or 1 but are dtype = object. Need to cast them to int.
obj_binary_cols = [col for col in df_encoded.columns 
                   if df_encoded[col].dtype == 'object' 
                   and set(df_encoded[col].dropna().unique()) == {0, 1}]

# %%
df_encoded[obj_binary_cols] = df_encoded[obj_binary_cols].astype(int)

# %%
# Out:
# gender              int64
# Partner             int64
# Dependents          int64
# PhoneService        int64
# PaperlessBilling    int64
# Churn               int64
# dtype: object

# %%
df_encoded.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df_encoded.dtypes
# Out:
# customerID              str
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling      int64
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                 int64
# dtype: object

# %%
df_encoded['OnlineSecurity'].unique()
# Out:
# <StringArray>
# ['No', 'Yes', 'No internet service']
# Length: 3, dtype: str

# %%
# 3 discrete string values.
#
yes_no_noInternet_cols = [col for col in df_encoded.columns 
        if set(df_encoded[col].dropna().unique()) == {'Yes', 'No', 'No internet service'}]
yes_no_noInternet_cols
# Out:
# ['OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies']

# %%
df_encoded[yes_no_noInternet_cols] = df_encoded[yes_no_noInternet_cols].replace({"No": 0, "Yes": 1, 3: 2}).astype(int)

# %%
df_encoded['OnlineSecurity'].unique()
# Out:
# array([0, 1, 2])

# %%
df_encoded.dtypes
# Out:
# customerID              str
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines           str
# InternetService         str
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract                str
# PaperlessBilling      int64
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                 int64
# dtype: object

# %%
df_encoded.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService     MultipleLines InternetService  OnlineSecurity  \
# 0             0  No phone service             DSL               0
# 1             1                No             DSL               1
# 2             1                No             DSL               1
# 3             0  No phone service             DSL               1
# 4             1                No     Fiber optic               0
#
#    OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0             1                 0            0            0                0
# ...

# %%
df_encoded['InternetService'].unique()
# Out:
# <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str

# %%
df_encoded['Contract'].unique()
# Out:
# <StringArray>
# ['Month-to-month', 'One year', 'Two year']
# Length: 3, dtype: str

# %%
# Should OHE here?
df_encoded['PaymentMethod'].unique()
# Out:
# <StringArray>
# [         'Electronic check',              'Mailed check',
#  'Bank transfer (automatic)',   'Credit card (automatic)']
# Length: 4, dtype: str

# %%
df_encoded['TotalCharges'] = df_encoded['TotalCharges'].astype(float)

# %%
df_encoded['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: str

# %%
df['TotalCharges'].str.strip().eq('').sum()
# Out:
# np.int64(11)

# %%
df[df['TotalCharges'].str.strip() == ''].index
# Out:
# Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %%
df_encoded.loc[488]
# Out:
# customerID                         4472-LVYGI
# gender                                      0
# SeniorCitizen                               0
# Partner                                     1
# Dependents                                  1
# tenure                                      0
# PhoneService                                0
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                              1
# OnlineBackup                                0
# DeviceProtection                            1
# TechSupport                                 1
# StreamingTV                                 1
# StreamingMovies                             0
# Contract                             Two year
# PaperlessBilling                            1
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                       0
# ...

# %%
df_encoded[df_encoded['TotalCharges'] == ' '].style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_814c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_814c3_level0_col0" class="col_heading level0 col0" >customerID</th>
#       <th id="T_814c3_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_814c3_level0_col2" class="col_heading level0 col2" >SeniorCitizen</th>
#       <th id="T_814c3_level0_col3" class="col_heading level0 col3" >Partner</th>
#       <th id="T_814c3_level0_col4" class="col_heading level0 col4" >Dependents</th>
#       <th id="T_814c3_level0_col5" class="col_heading level0 col5" >tenure</th>
#       <th id="T_814c3_level0_col6" class="col_heading level0 col6" >PhoneService</th>
#       <th id="T_814c3_level0_col7" class="col_heading level0 col7" >MultipleLines</th>
#       <th id="T_814c3_level0_col8" class="col_heading level0 col8" >InternetService</th>
#       <th id="T_814c3_level0_col9" class="col_heading level0 col9" >OnlineSecurity</th>
# ...

# %%
mask = df_encoded['TotalCharges'].str.strip() == ''
df_encoded.loc[mask, 'TotalCharges'] = (df_encoded.loc[mask, 'tenure'] * df_encoded.loc[mask, 'MonthlyCharges']).astype(str)

# %%
df_encoded['tenure'] * df_encoded['MonthlyCharges']
# Out:
# 0        29.85
# 1      1936.30
# 2       107.70
# 3      1903.50
# 4       141.40
#          ...
# 7038   2035.20
# 7039   7430.40
# 7040    325.60
# 7041    297.60
# 7042   6972.90
# Length: 7043, dtype: float64

# %%
df_encoded.TotalCharges[7042]
# Out:
# np.float64(6844.5)

# %%
df_encoded.dtypes
# Out:
# customerID              str
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines           str
# InternetService         str
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract                str
# PaperlessBilling      int64
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService     MultipleLines InternetService  OnlineSecurity  \
# 0             0  No phone service             DSL               0
# 1             1                No             DSL               1
# 2             1                No             DSL               1
# 3             0  No phone service             DSL               1
# 4             1                No     Fiber optic               0
#
#    OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0             1                 0            0            0                0
# ...

# %%
df_encoded.MultipleLines.unique()
# Out:
# <StringArray>
# ['No phone service', 'No', 'Yes']
# Length: 3, dtype: str

# %%
df_encoded['MultipleLines'] = df_encoded['MultipleLines'].replace({"No": 0, 'Yes': 1, 'No phone service': 2})

# %%
df_encoded.MultipleLines.unique()
# Out:
# array([2, 0], dtype=object)

# %%
df_encoded['MultipleLines'] = df_encoded['MultipleLines'].replace({"No": 0, 'Yes': 1, 'No phone service': 2}).astype(int)

# %%
df_encoded['MultipleLines'].dtypes
# Out:
# dtype('int64')

# %%
df2['MultipleLines'].unique()
# Out:
# <StringArray>
# ['No phone service', 'No', 'Yes']
# Length: 3, dtype: str

# %%
df_encoded.dtypes
# Out:
# customerID              str
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService         str
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract                str
# PaperlessBilling      int64
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
df_encoded.InternetService .unique()
# Out:
# <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str

# %%
df_encoded2 = df_encoded.copy()

# %%
df_encoded.PaymentMethod.unique()
# Out:
# <StringArray>
# [         'Electronic check',              'Mailed check',
#  'Bank transfer (automatic)',   'Credit card (automatic)']
# Length: 4, dtype: str

# %%
df_encoded.Contract.unique()
# Out:
# <StringArray>
# ['Month-to-month', 'One year', 'Two year']
# Length: 3, dtype: str

# %%
df_encoded2.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService  MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0             0              2             DSL               0             1
# 1             1              0             DSL               1             0
# 2             1              0             DSL               1             1
# 3             0              2             DSL               1             0
# 4             1              0     Fiber optic               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# ...

# %%
df_encoded = pd.get_dummies(df_encoded, columns=['InternetService', 'PaymentMethod'], dtype=int)

# %%
df_encoded.dtypes
# Out:
# customerID                                     str
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# Contract                                       str
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# ...

# %%
df_encoded.Contract.unique()
# Out:
# <StringArray>
# ['Month-to-month', 'One year', 'Two year']
# Length: 3, dtype: str

# %%
df_encoded['Contract'] = df_encoded['Contract'].map({'Month-to-month': 0, 'One year': 1, 'Two year': 2})

# %%
df_encoded.dtypes
# Out:
# customerID                                     str
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# Contract                                     int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# ...

# %%
df_new = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df_new.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
from helpers import encode_data
import pandas as pd

# %%
encode_data(df_new).dtypes
# Out:
# customerID                                     str
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# Contract                                     int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# ...

# %%
df_new.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df_new.OnlineBackup.unique()
# Out:
# <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
